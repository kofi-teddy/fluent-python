# %%
import numpy

# find the mean of the array
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %%
# find the median of the array

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)
x
# Out:
# np.float64(87.0)

# %%
from scipy import stats

# find the frequency of the array
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)
x
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))

# %%
import numpy

# Standard deviation is a number that describes how spread out the values are.
# A low standard deviation means that most of the numbers are close to the mean (average) value.
# A high standard deviation means that the values are spread out over a wider range.

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)
x
# Out:
# np.float64(0.9035079029052513)

# %%
# Variance 
# is another number that indicates how spread out the values are.
# if you take the square root of the variance, you get the standard deviation.
# if you multiply the standard deviation by itself, you get the variance.
# To calculate the variance you have to do as follows:
# 1. Find the mean
# 2. For each value: find the difference from the mean
# 3. For each difference: find the square value
# 4. The variance is the average number of these squared differences

speed = [32,111,138,28,59,77,97]
x = numpy.var(speed)
x
# Out:
# np.float64(1432.2448979591834)

# %%
# Percentiles 
# describes the value that a given percent of the values are lower than.
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
x = numpy.percentile(ages, 75)
print(x)
x = numpy.percentile(ages, 90)
print(x)
# Out:
# 43.0
# 61.0

# %%
# Data Distribution
# random data sets
x = numpy.random.uniform(0.0, 5.0, 250)
print(x)
# Out:
# [1.68672121 0.90400626 1.00316746 1.50199611 4.38001006 4.10744599
#  0.05469585 3.80452329 4.6952049  1.21542054 4.3115975  1.67942983
#  2.34084025 0.15330617 1.81887995 2.84637889 4.82470784 2.69035421
#  2.38331512 3.8219793  1.695781   0.80352742 4.3823735  3.87150129
#  4.23322887 1.46271739 0.98520127 2.13327424 2.94180834 0.34036885
#  4.05102738 2.65325816 4.6652047  0.52826141 3.76249551 4.70545856
#  0.57934529 0.52005761 3.55595216 2.13730641 1.9322064  3.98381236
#  0.22942417 3.48270739 3.6990031  2.13253925 2.58145065 2.85041511
#  3.93555642 3.55447565 3.83494733 4.44151512 0.3452551  1.89825119
#  4.67967849 1.43579361 1.57975494 2.2340923  3.89298545 3.50874453
#  3.58020587 2.6907508  3.85747901 2.91775892 0.17912421 4.48692705
#  3.12480856 2.36339471 4.36518586 3.18238294 2.98065285 1.86398626
#  1.52094296 2.75464767 0.55699247 1.09319037 3.62286212 1.5521662
#  3.66795032 3.92599125 1.83340953 2.08230802 1.69505019 3.64412516
#  2.23518859 3.20697505 4.10967683 0.67156743 1.32412819 2.92344311
#  0.41588792 2.79234436 0.11794646 2.37686323 1.55134661 4.96669743
#  2.52546507 3.07074186 1.37672229 3.3906413  1.72759277 1.59929094
#  1.23800618 1.0817515  0.50469998 3.50907794 4.52784923 3.31088353
#  0.66013123 1.89695168 0.55740896 1.51402715 2.32548579 0.1894664
#  0.65641645 1.8397039  1.3136127  2.37041937 4.08254944 4.18083164
#  1.64468528 2.92070157 1.40365069 0.44015745 4.23333823 3.1913865
#  2.66616674 2.19411891 0.37928311 2.39823006 0.99621564 3.65051344
#  1.44295128 3.51848498 2.85654606 2.89341872 0.27250518 1.67311391
#  3.49681041 4.03828429 1.61736255 4.70401906 1.09966855 0.89489186
#  2.61805519 1.34807276 1.6053535  4.59638731 1.54074776 2.50981715
#  1.28501831 4.73594701 1.64568227 1.42054011 0.71146016 4.25211138
#  1.36917907 1.77769956 3.18482094 4.69822319 4.86291321 3.17486678
#  0.64293921 3.97836662 0.38900876 1.50644151 1.40062476 3.99382322
#  0.40119009 2.79348816 0.1893582  0.51197997 0.19502546 2.4847927
#  1.47608293 1.56533251 1.8553299  1.41807163 2.68624734 1.07776895
#  4.10467466 4.76066198 0.48209018 1.63521188 3.92796375 0.53567282
#  1.85978056 3.6823326  2.71919376 3.29069399 0.75289433 4.99246178
#  3.61823526 1.54069058 1.18608184 4.03144736 4.1234689  2.41675363
#  1.40129794 1.02329264 4.81763806 1.96688058 1.25416852 4.20452299
#  4.4407026  0.35477966 4.6025869  0.40485451 3.67970024 4.08984679
#  1.56080201 2.34152674 0.48805899 4.01491677 1.24115481 1.58669954
#  4.58635648 2.89862182 4.92582604 3.98676958 2.93085344 2.37326838
#  1.00557048 4.2452682  0.97151048 4.58451151 4.07386711 3.50962151
#  4.33433832 0.52236248 4.68920918 0.75483464 2.06933719 2.79098327
#  2.44905966 3.85538238 3.14648709 1.70028064 2.09046154 1.87687574
#  1.9167574  1.8326144  1.67174084 0.45917286 4.43743299 3.94783578
#  4.32742394 1.25903468 3.05413736 4.72127305]

# %%
# Histogram
# visualize the data set using the histogram
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)
plt.hist(x, 5)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Big Data Distributions

x = numpy.random.uniform(0.0, 5.0, 100000)
plt.hist(x, 100)
plt.show()

# %%
# Normal Data Distribution or Gaussian data distribution
# an array where the values are concentrated around a given value.
# the mean value is 5.0, and the standard deviation is 1.0
# 100000 values

x = numpy.random.normal(5.0, 1.0, 100000)
plt.hist(x, 100)
plt.show()

# %%
# Scatter Plot
# a diagram where each value in the data set is represented by a dot
# The Matplotlib module has a method for drawing scatter plots, it 
# needs two arrays of the same length, one for the values of 
# the x-axis, and one for the values of the y-axis

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x, y)
plt.show()

# %%
# Random Data Distributions
# scatter plot with 1000

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)
plt.scatter(x, y)
plt.show()

# %%
# Regression
# used when you try to find the relationship between variables.
# used to predict the outcome of future events

# Linear Regression
# uses the relationship between the data-points to draw 
# a straight line through all them
# This line can be used to predict future values

from scipy import stats


x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
# R for Relationship
# This relationship - the coefficient of correlation - is called r.
# The r value ranges from -1 to 1, where 0 means no relationship,
# and 1 (and -1) means 100% related.

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# -0.7585915243761551

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)
print(speed)
# Out:
# 85.59308314937454

# %%
# Bad Fit
# linear regression would not be the best 
# method to predict future values

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

print(r)

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# 0.01331814154297493

# %%
# Polynomial Regression
# If data points clearly does not fit a 
# linear regression (a straight line through all data points), 
# it might be ideal for polynomial regression.
# uses the relationship between the variables x and y 
# to find the best way to draw a line through the data points.

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
# R-Squared
# The relationship for polynomial regression is 
# measured with a value called the r-squared.
# The r-squared value ranges from 0 to 1, where
# 0 means no relationship, and 1 means 100% related.

from sklearn.metrics import r2_score


x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451025

# %%
# Predict Future Values

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269697975

# %%
# Bad Fit
# where polynomial regression would not be the 
# best method to predict future values.


x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))      
myline = numpy.linspace(2, 95, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
# Out:
# 0.009952707566680541
